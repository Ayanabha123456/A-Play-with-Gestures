# %%
import pickle
from keras_preprocessing.image import ImageDataGenerator
import pandas as pd
import numpy as np

# %%
#using VGGNet features
import tensorflow as tf
pre_model=tf.keras.applications.VGG16(include_top=False,
                                        input_shape=(64,64,3),
                                        pooling='avg',
                                        weights='imagenet')

# %%
for layer in pre_model.layers:
    layer.trainable=False

# %%
#creating model
model=tf.keras.models.Sequential()
model.add(pre_model)
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(32,activation='relu'))
model.add(tf.keras.layers.Dense(24,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 32)                16416
#
#  dense_1 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 14,731,896
# Trainable params: 17,208
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# # ASL fingerspell dataset

# %%
x=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\x_asl_fingerspell.pkl','rb'))
y=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\y_asl_fingerspell.pkl','rb'))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
data={'id':X_train,'sign':y_train}
df1=pd.DataFrame(data)
df1
# Out:
#                                                       id sign
# 0      D:\Capstone utilities\Datasets\ASL_fingerspell...    k
# 1      D:\Capstone utilities\Datasets\ASL_fingerspell...    x
# 2      D:\Capstone utilities\Datasets\ASL_fingerspell...    s
# 3      D:\Capstone utilities\Datasets\ASL_fingerspell...    r
# 4      D:\Capstone utilities\Datasets\ASL_fingerspell...    y
# ...                                                  ...  ...
# 52614  D:\Capstone utilities\Datasets\ASL_fingerspell...    u
# 52615  D:\Capstone utilities\Datasets\ASL_fingerspell...    m
# 52616  D:\Capstone utilities\Datasets\ASL_fingerspell...    d
# 52617  D:\Capstone utilities\Datasets\ASL_fingerspell...    b
# 52618  D:\Capstone utilities\Datasets\ASL_fingerspell...    f
#
# [52619 rows x 2 columns]

# %%
data={'id':X_test,'sign':y_test}
df2=pd.DataFrame(data)
df2
# Out:
#                                                       id sign
# 0      D:\Capstone utilities\Datasets\ASL_fingerspell...    o
# 1      D:\Capstone utilities\Datasets\ASL_fingerspell...    k
# 2      D:\Capstone utilities\Datasets\ASL_fingerspell...    g
# 3      D:\Capstone utilities\Datasets\ASL_fingerspell...    d
# 4      D:\Capstone utilities\Datasets\ASL_fingerspell...    k
# ...                                                  ...  ...
# 13150  D:\Capstone utilities\Datasets\ASL_fingerspell...    g
# 13151  D:\Capstone utilities\Datasets\ASL_fingerspell...    v
# 13152  D:\Capstone utilities\Datasets\ASL_fingerspell...    g
# 13153  D:\Capstone utilities\Datasets\ASL_fingerspell...    b
# 13154  D:\Capstone utilities\Datasets\ASL_fingerspell...    g
#
# [13155 rows x 2 columns]

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_dataframe(dataframe=df1,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 52619 validated image filenames belonging to 24 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
testing_set = test_datagen.flow_from_dataframe(dataframe=df2,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 13155 validated image filenames belonging to 24 classes.

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(training_set,validation_data=testing_set,epochs=15)
# Out:
# Epoch 1/15
# 1645/1645 [==============================] - 1258s 760ms/step - loss: 2.0148 - accuracy: 0.4116 - val_loss: 1.3602 - val_accuracy: 0.5802
# Epoch 2/15
# 1645/1645 [==============================] - 127s 77ms/step - loss: 1.3090 - accuracy: 0.6019 - val_loss: 1.0699 - val_accuracy: 0.6732
# Epoch 3/15
# 1645/1645 [==============================] - 154s 93ms/step - loss: 1.1306 - accuracy: 0.6531 - val_loss: 0.9339 - val_accuracy: 0.7159
# Epoch 4/15
# 1645/1645 [==============================] - 166s 100ms/step - loss: 1.0328 - accuracy: 0.6791 - val_loss: 0.8568 - val_accuracy: 0.7426
# Epoch 5/15
# 1645/1645 [==============================] - 215s 131ms/step - loss: 0.9694 - accuracy: 0.6978 - val_loss: 0.8225 - val_accuracy: 0.7444
# Epoch 6/15
# 1645/1645 [==============================] - 186s 113ms/step - loss: 0.9322 - accuracy: 0.7052 - val_loss: 0.7806 - val_accuracy: 0.7549
# Epoch 7/15
# 1645/1645 [==============================] - 178s 108ms/step - loss: 0.8933 - accuracy: 0.7168 - val_loss: 0.7598 - val_accuracy: 0.7599
# Epoch 8/15
# 1645/1645 [==============================] - 179s 109ms/step - loss: 0.8686 - accuracy: 0.7252 - val_loss: 0.7459 - val_accuracy: 0.7606
# Epoch 9/15
# 1645/1645 [==============================] - 183s 111ms/step - loss: 0.8490 - accuracy: 0.7312 - val_loss: 0.7263 - val_accuracy: 0.7710
# Epoch 10/15
# 1645/1645 [==============================] - 176s 107ms/step - loss: 0.8307 - accuracy: 0.7346 - val_loss: 0.7098 - val_accuracy: 0.7695
# Epoch 11/15
# 1645/1645 [==============================] - 177s 108ms/step - loss: 0.8176 - accuracy: 0.7399 - val_loss: 0.6847 - val_accuracy: 0.7815
# Epoch 12/15
# 1645/1645 [==============================] - 175s 106ms/step - loss: 0.8077 - accuracy: 0.7433 - val_loss: 0.6993 - val_accuracy: 0.7754
# Epoch 13/15
# 1645/1645 [==============================] - 178s 108ms/step - loss: 0.7968 - accuracy: 0.7486 - val_loss: 0.6663 - val_accuracy: 0.7875
# Epoch 14/15
# 1645/1645 [==============================] - 178s 108ms/step - loss: 0.7870 - accuracy: 0.7507 - val_loss: 0.6771 - val_accuracy: 0.7827
# Epoch 15/15
# 1645/1645 [==============================] - 179s 109ms/step - loss: 0.7815 - accuracy: 0.7515 - val_loss: 0.6701 - val_accuracy: 0.7811

# %% [markdown]
# # ISL digits

# %%
x=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\x_ISL_digits.pkl','rb'))
y=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\y_ISL_digits.pkl','rb'))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=250/len(x))

# %%
data={'id':X_train,'sign':y_train}
df1=pd.DataFrame(data)
df1
# Out:
#                                                      id sign
# 0     D:\Capstone utilities\Datasets\ISL digits\5\10...    5
# 1     D:\Capstone utilities\Datasets\ISL digits\1\19...    1
# 2     D:\Capstone utilities\Datasets\ISL digits\5\19...    5
# 3     D:\Capstone utilities\Datasets\ISL digits\2\17...    2
# 4     D:\Capstone utilities\Datasets\ISL digits\7\12...    7
# ...                                                 ...  ...
# 1745  D:\Capstone utilities\Datasets\ISL digits\5\35...    5
# 1746  D:\Capstone utilities\Datasets\ISL digits\6\18...    6
# 1747  D:\Capstone utilities\Datasets\ISL digits\4\15...    4
# 1748  D:\Capstone utilities\Datasets\ISL digits\7\15...    7
# 1749  D:\Capstone utilities\Datasets\ISL digits\5\30...    5
#
# [1750 rows x 2 columns]

# %%
data={'id':X_test,'sign':y_test}
df2=pd.DataFrame(data)
df2
# Out:
#                                                     id sign
# 0    D:\Capstone utilities\Datasets\ISL digits\9\15...    9
# 1    D:\Capstone utilities\Datasets\ISL digits\1\57...    1
# 2    D:\Capstone utilities\Datasets\ISL digits\6\39...    6
# 3    D:\Capstone utilities\Datasets\ISL digits\4\19...    4
# 4    D:\Capstone utilities\Datasets\ISL digits\6\18...    6
# ..                                                 ...  ...
# 245  D:\Capstone utilities\Datasets\ISL digits\0\22...    0
# 246  D:\Capstone utilities\Datasets\ISL digits\4\12...    4
# 247  D:\Capstone utilities\Datasets\ISL digits\9\41...    9
# 248  D:\Capstone utilities\Datasets\ISL digits\4\10...    4
# 249  D:\Capstone utilities\Datasets\ISL digits\6\19...    6
#
# [250 rows x 2 columns]

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_dataframe(dataframe=df1,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 1750 validated image filenames belonging to 10 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
testing_set = test_datagen.flow_from_dataframe(dataframe=df2,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 250 validated image filenames belonging to 10 classes.

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(training_set,validation_data=testing_set,epochs=15)
# Out:
# Epoch 1/15
# 55/55 [==============================] - 24s 331ms/step - loss: 2.0648 - accuracy: 0.3451 - val_loss: 1.7760 - val_accuracy: 0.4640
# Epoch 2/15
# 55/55 [==============================] - 5s 81ms/step - loss: 1.5432 - accuracy: 0.6257 - val_loss: 1.2668 - val_accuracy: 0.8080
# Epoch 3/15
# 55/55 [==============================] - 5s 84ms/step - loss: 1.1174 - accuracy: 0.7983 - val_loss: 0.8987 - val_accuracy: 0.9120
# Epoch 4/15
# 55/55 [==============================] - 5s 82ms/step - loss: 0.8135 - accuracy: 0.8646 - val_loss: 0.6708 - val_accuracy: 0.9200
# Epoch 5/15
# 55/55 [==============================] - 5s 82ms/step - loss: 0.6384 - accuracy: 0.8943 - val_loss: 0.5315 - val_accuracy: 0.9520
# Epoch 6/15
# 55/55 [==============================] - 4s 81ms/step - loss: 0.5121 - accuracy: 0.9280 - val_loss: 0.4322 - val_accuracy: 0.9560
# Epoch 7/15
# 55/55 [==============================] - 5s 83ms/step - loss: 0.4181 - accuracy: 0.9451 - val_loss: 0.3390 - val_accuracy: 0.9840
# Epoch 8/15
# 55/55 [==============================] - 5s 85ms/step - loss: 0.3547 - accuracy: 0.9491 - val_loss: 0.2804 - val_accuracy: 0.9680
# Epoch 9/15
# 55/55 [==============================] - 5s 83ms/step - loss: 0.3108 - accuracy: 0.9560 - val_loss: 0.2580 - val_accuracy: 0.9760
# Epoch 10/15
# 55/55 [==============================] - 5s 84ms/step - loss: 0.2650 - accuracy: 0.9600 - val_loss: 0.1997 - val_accuracy: 0.9880
# Epoch 11/15
# 55/55 [==============================] - 5s 83ms/step - loss: 0.2312 - accuracy: 0.9686 - val_loss: 0.1856 - val_accuracy: 0.9840
# Epoch 12/15
# 55/55 [==============================] - 5s 83ms/step - loss: 0.2071 - accuracy: 0.9697 - val_loss: 0.1700 - val_accuracy: 0.9840
# Epoch 13/15
# 55/55 [==============================] - 5s 82ms/step - loss: 0.1922 - accuracy: 0.9680 - val_loss: 0.1373 - val_accuracy: 0.9840
# Epoch 14/15
# 55/55 [==============================] - 5s 82ms/step - loss: 0.1670 - accuracy: 0.9754 - val_loss: 0.1187 - val_accuracy: 0.9920
# Epoch 15/15
# 55/55 [==============================] - 5s 83ms/step - loss: 0.1522 - accuracy: 0.9800 - val_loss: 0.1167 - val_accuracy: 0.9920

# %% [markdown]
# # NUS II dataset

# %%
x=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\x_nus_II.pkl','rb'))
y=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\y_nus_II.pkl','rb'))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=250/len(x))

# %%
data={'id':X_train,'sign':y_train}
df1=pd.DataFrame(data)
df1
# Out:
#                                                      id sign
# 0     D:\Capstone utilities\Datasets\NUS Hand Postur...    f
# 1     D:\Capstone utilities\Datasets\NUS Hand Postur...    b
# 2     D:\Capstone utilities\Datasets\NUS Hand Postur...    f
# 3     D:\Capstone utilities\Datasets\NUS Hand Postur...    c
# 4     D:\Capstone utilities\Datasets\NUS Hand Postur...    h
# ...                                                 ...  ...
# 1745  D:\Capstone utilities\Datasets\NUS Hand Postur...    f
# 1746  D:\Capstone utilities\Datasets\NUS Hand Postur...    g
# 1747  D:\Capstone utilities\Datasets\NUS Hand Postur...    e
# 1748  D:\Capstone utilities\Datasets\NUS Hand Postur...    h
# 1749  D:\Capstone utilities\Datasets\NUS Hand Postur...    f
#
# [1750 rows x 2 columns]

# %%
data={'id':X_test,'sign':y_test}
df2=pd.DataFrame(data)
df2
# Out:
#                                                     id sign
# 0    D:\Capstone utilities\Datasets\NUS Hand Postur...    j
# 1    D:\Capstone utilities\Datasets\NUS Hand Postur...    b
# 2    D:\Capstone utilities\Datasets\NUS Hand Postur...    g
# 3    D:\Capstone utilities\Datasets\NUS Hand Postur...    e
# 4    D:\Capstone utilities\Datasets\NUS Hand Postur...    g
# ..                                                 ...  ...
# 245  D:\Capstone utilities\Datasets\NUS Hand Postur...    a
# 246  D:\Capstone utilities\Datasets\NUS Hand Postur...    e
# 247  D:\Capstone utilities\Datasets\NUS Hand Postur...    j
# 248  D:\Capstone utilities\Datasets\NUS Hand Postur...    e
# 249  D:\Capstone utilities\Datasets\NUS Hand Postur...    g
#
# [250 rows x 2 columns]

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_dataframe(dataframe=df1,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 1750 validated image filenames belonging to 10 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
testing_set = test_datagen.flow_from_dataframe(dataframe=df2,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 250 validated image filenames belonging to 10 classes.

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(training_set,validation_data=testing_set,epochs=50)
# Out:
# Epoch 1/50
# 55/55 [==============================] - 5s 71ms/step - loss: 2.2887 - accuracy: 0.1503 - val_loss: 2.1973 - val_accuracy: 0.2040
# Epoch 2/50
# 55/55 [==============================] - 4s 63ms/step - loss: 2.1096 - accuracy: 0.2440 - val_loss: 2.0515 - val_accuracy: 0.2880
# Epoch 3/50
# 55/55 [==============================] - 4s 66ms/step - loss: 1.9895 - accuracy: 0.3154 - val_loss: 1.9417 - val_accuracy: 0.3560
# Epoch 4/50
# 55/55 [==============================] - 4s 65ms/step - loss: 1.8886 - accuracy: 0.3480 - val_loss: 1.8904 - val_accuracy: 0.3240
# 55/55 [==============================] - 4s 76ms/step - loss: 0.8527 - accuracy: 0.7286 - val_loss: 1.0159 - val_accuracy: 0.6720
# Epoch 44/50
# 55/55 [==============================] - 4s 77ms/step - loss: 0.8482 - accuracy: 0.7240 - val_loss: 1.0249 - val_accuracy: 0.6520
# Epoch 45/50
# 55/55 [==============================] - 4s 81ms/step - loss: 0.8359 - accuracy: 0.7194 - val_loss: 1.0144 - val_accuracy: 0.6400
# Epoch 46/50
# 55/55 [==============================] - 4s 77ms/step - loss: 0.8080 - accuracy: 0.7434 - val_loss: 1.0310 - val_accuracy: 0.6320
# Epoch 47/50
# 55/55 [==============================] - 4s 79ms/step - loss: 0.8009 - accuracy: 0.7474 - val_loss: 0.9935 - val_accuracy: 0.6440
# Epoch 48/50
# 55/55 [==============================] - 5s 82ms/step - loss: 0.8089 - accuracy: 0.7354 - val_loss: 1.0309 - val_accuracy: 0.6320
# Epoch 49/50
# 55/55 [==============================] - 4s 79ms/step - loss: 0.7810 - accuracy: 0.7543 - val_loss: 1.0029 - val_accuracy: 0.6480
# Epoch 50/50
# 55/55 [==============================] - 4s 79ms/step - loss: 0.8037 - accuracy: 0.7354 - val_loss: 0.9931 - val_accuracy: 0.6560

# %% [markdown]
# # Cambridge hand gesture dataset

# %%
x=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\x_cambridge.pkl','rb'))
y=pickle.load(open('C:\\Users\\Ayanabha\\Capstone\\Pickles\\y_cambridge.pkl','rb'))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
data={'id':X_train,'sign':y_train}
df1=pd.DataFrame(data)
df1
# Out:
#                                                       id sign
# 0      D:\Capstone utilities\Datasets\Cambridge_Hand_...    1
# 1      D:\Capstone utilities\Datasets\Cambridge_Hand_...    3
# 2      D:\Capstone utilities\Datasets\Cambridge_Hand_...    5
# 3      D:\Capstone utilities\Datasets\Cambridge_Hand_...    8
# 4      D:\Capstone utilities\Datasets\Cambridge_Hand_...    5
# ...                                                  ...  ...
# 50545  D:\Capstone utilities\Datasets\Cambridge_Hand_...    9
# 50546  D:\Capstone utilities\Datasets\Cambridge_Hand_...    6
# 50547  D:\Capstone utilities\Datasets\Cambridge_Hand_...    1
# 50548  D:\Capstone utilities\Datasets\Cambridge_Hand_...    3
# 50549  D:\Capstone utilities\Datasets\Cambridge_Hand_...    8
#
# [50550 rows x 2 columns]

# %%
data={'id':X_test,'sign':y_test}
df2=pd.DataFrame(data)
df2
# Out:
#                                                       id sign
# 0      D:\Capstone utilities\Datasets\Cambridge_Hand_...    2
# 1      D:\Capstone utilities\Datasets\Cambridge_Hand_...    3
# 2      D:\Capstone utilities\Datasets\Cambridge_Hand_...    3
# 3      D:\Capstone utilities\Datasets\Cambridge_Hand_...    2
# 4      D:\Capstone utilities\Datasets\Cambridge_Hand_...    7
# ...                                                  ...  ...
# 12633  D:\Capstone utilities\Datasets\Cambridge_Hand_...    7
# 12634  D:\Capstone utilities\Datasets\Cambridge_Hand_...    8
# 12635  D:\Capstone utilities\Datasets\Cambridge_Hand_...    1
# 12636  D:\Capstone utilities\Datasets\Cambridge_Hand_...    9
# 12637  D:\Capstone utilities\Datasets\Cambridge_Hand_...    9
#
# [12638 rows x 2 columns]

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
# 1    D:\Capstone utilities\Datasets\NUS Hand Postur...   g1
# 2    D:\Capstone utilities\Datasets\NUS Hand Postur...   g1
# 3    D:\Capstone utilities\Datasets\NUS Hand Postur...   g1
# 4    D:\Capstone utilities\Datasets\NUS Hand Postur...   g1
# ..                                                 ...  ...
# 235  D:\Capstone utilities\Datasets\NUS Hand Postur...   g9
# 236  D:\Capstone utilities\Datasets\NUS Hand Postur...   g9
# 237  D:\Capstone utilities\Datasets\NUS Hand Postur...   g9
# 238  D:\Capstone utilities\Datasets\NUS Hand Postur...   g9
# 239  D:\Capstone utilities\Datasets\NUS Hand Postur...   g9
#
# [240 rows x 2 columns]

# %%
test_indices=[21,22,23,45,46,47,69,70,71,93,94,95,117,118,119,142,143,166,167,190,191,214,215,238,239]
ind=df.index.isin(test_indices)
df1=df[~ind]
df2=df[ind]

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_dataframe(dataframe=df1,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 215 validated image filenames belonging to 10 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
testing_set = test_datagen.flow_from_dataframe(dataframe=df2,
                                                directory=None,
                                                x_col="id", y_col="sign",
                                                batch_size=32, seed=42,
                                                class_mode="categorical",
                                                target_size=(64,64))
# Out:
# Found 25 validated image filenames belonging to 10 classes.

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(training_set,validation_data=testing_set,epochs=50)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 2s 142ms/step - loss: 2.4585 - accuracy: 0.1116 - val_loss: 2.3279 - val_accuracy: 0.1600
# Epoch 2/50
# 7/7 [==============================] - 1s 70ms/step - loss: 2.2651 - accuracy: 0.1535 - val_loss: 2.2297 - val_accuracy: 0.2400
# Epoch 3/50
# 7/7 [==============================] - 1s 76ms/step - loss: 2.1771 - accuracy: 0.3349 - val_loss: 2.1349 - val_accuracy: 0.3600
# Epoch 4/50
# 7/7 [==============================] - 1s 73ms/step - loss: 2.1058 - accuracy: 0.3953 - val_loss: 2.0575 - val_accuracy: 0.4400
# Epoch 5/50
# 7/7 [==============================] - 1s 74ms/step - loss: 2.0514 - accuracy: 0.4000 - val_loss: 1.9898 - val_accuracy: 0.4400
# Epoch 6/50
# 7/7 [==============================] - 1s 77ms/step - loss: 1.9997 - accuracy: 0.4558 - val_loss: 1.9330 - val_accuracy: 0.4800
# Epoch 7/50
# 7/7 [==============================] - 1s 75ms/step - loss: 1.9395 - accuracy: 0.5349 - val_loss: 1.8506 - val_accuracy: 0.6000
# Epoch 8/50
# 7/7 [==============================] - 1s 71ms/step - loss: 1.8689 - accuracy: 0.5628 - val_loss: 1.7873 - val_accuracy: 0.7200
# Epoch 9/50
# 7/7 [==============================] - 1s 77ms/step - loss: 1.8228 - accuracy: 0.5814 - val_loss: 1.7288 - val_accuracy: 0.7200
# Epoch 10/50
# 7/7 [==============================] - 1s 70ms/step - loss: 1.7716 - accuracy: 0.6140 - val_loss: 1.6680 - val_accuracy: 0.7200
# Epoch 11/50
# 7/7 [==============================] - 1s 74ms/step - loss: 1.7226 - accuracy: 0.6279 - val_loss: 1.6099 - val_accuracy: 0.7600
# Epoch 12/50
# 7/7 [==============================] - 1s 72ms/step - loss: 1.6818 - accuracy: 0.5860 - val_loss: 1.5544 - val_accuracy: 0.7600
# Epoch 13/50
# 7/7 [==============================] - 1s 73ms/step - loss: 1.6363 - accuracy: 0.6419 - val_loss: 1.5079 - val_accuracy: 0.8400
# Epoch 14/50
# 7/7 [==============================] - 1s 73ms/step - loss: 1.5813 - accuracy: 0.6837 - val_loss: 1.4611 - val_accuracy: 0.7600
# Epoch 15/50
# 7/7 [==============================] - 1s 78ms/step - loss: 1.5215 - accuracy: 0.6977 - val_loss: 1.4006 - val_accuracy: 0.8800
# Epoch 16/50
# 7/7 [==============================] - 1s 79ms/step - loss: 1.5151 - accuracy: 0.6744 - val_loss: 1.3551 - val_accuracy: 0.8800
# Epoch 17/50
# 7/7 [==============================] - 1s 75ms/step - loss: 1.4454 - accuracy: 0.6744 - val_loss: 1.3141 - val_accuracy: 0.9200
# Epoch 18/50
# 7/7 [==============================] - 1s 75ms/step - loss: 1.4304 - accuracy: 0.7023 - val_loss: 1.2678 - val_accuracy: 0.9200
# Epoch 19/50
# 7/7 [==============================] - 1s 70ms/step - loss: 1.3838 - accuracy: 0.7209 - val_loss: 1.2232 - val_accuracy: 0.8800
# Epoch 20/50
# 7/7 [==============================] - 1s 70ms/step - loss: 1.3439 - accuracy: 0.7349 - val_loss: 1.1851 - val_accuracy: 0.9200
# Epoch 21/50
# 7/7 [==============================] - 1s 78ms/step - loss: 1.2948 - accuracy: 0.7814 - val_loss: 1.1348 - val_accuracy: 0.8800
# Epoch 22/50
# 7/7 [==============================] - 1s 78ms/step - loss: 1.2526 - accuracy: 0.7581 - val_loss: 1.0961 - val_accuracy: 0.9200
# Epoch 23/50
# 7/7 [==============================] - 1s 78ms/step - loss: 1.2321 - accuracy: 0.7814 - val_loss: 1.0527 - val_accuracy: 0.8800
# Epoch 24/50
# 7/7 [==============================] - 1s 74ms/step - loss: 1.1819 - accuracy: 0.7860 - val_loss: 1.0249 - val_accuracy: 0.9200
# Epoch 25/50
# 7/7 [==============================] - 1s 71ms/step - loss: 1.1366 - accuracy: 0.8000 - val_loss: 0.9749 - val_accuracy: 0.9200
# Epoch 26/50
# 7/7 [==============================] - 1s 72ms/step - loss: 1.1199 - accuracy: 0.8000 - val_loss: 0.9273 - val_accuracy: 0.9200
# Epoch 27/50
# 7/7 [==============================] - 1s 76ms/step - loss: 1.0699 - accuracy: 0.8279 - val_loss: 0.8908 - val_accuracy: 0.9600
# Epoch 28/50
# 7/7 [==============================] - 1s 75ms/step - loss: 1.0606 - accuracy: 0.8000 - val_loss: 0.8555 - val_accuracy: 0.9200
# Epoch 29/50
# 7/7 [==============================] - 1s 70ms/step - loss: 1.0395 - accuracy: 0.8419 - val_loss: 0.8326 - val_accuracy: 0.9600
# Epoch 30/50
# 7/7 [==============================] - 1s 73ms/step - loss: 0.9929 - accuracy: 0.8186 - val_loss: 0.8011 - val_accuracy: 0.9600
# Epoch 31/50
# 7/7 [==============================] - 1s 78ms/step - loss: 0.9590 - accuracy: 0.8465 - val_loss: 0.7672 - val_accuracy: 0.9600
# Epoch 32/50
# 7/7 [==============================] - 1s 73ms/step - loss: 0.9544 - accuracy: 0.8558 - val_loss: 0.7408 - val_accuracy: 0.9600
# Epoch 33/50
# 7/7 [==============================] - 1s 71ms/step - loss: 0.9336 - accuracy: 0.8558 - val_loss: 0.7156 - val_accuracy: 0.9600
# Epoch 34/50
# 7/7 [==============================] - 1s 70ms/step - loss: 0.8957 - accuracy: 0.8605 - val_loss: 0.6956 - val_accuracy: 0.9600
# Epoch 35/50
# 7/7 [==============================] - 1s 77ms/step - loss: 0.8445 - accuracy: 0.8744 - val_loss: 0.6787 - val_accuracy: 0.9200
# Epoch 36/50
# 7/7 [==============================] - 1s 73ms/step - loss: 0.7985 - accuracy: 0.8884 - val_loss: 0.6511 - val_accuracy: 0.9600
# Epoch 37/50
# 7/7 [==============================] - 1s 73ms/step - loss: 0.8236 - accuracy: 0.9023 - val_loss: 0.6281 - val_accuracy: 0.9600
# Epoch 38/50
# 7/7 [==============================] - 1s 69ms/step - loss: 0.8097 - accuracy: 0.8837 - val_loss: 0.6095 - val_accuracy: 0.9200
# Epoch 39/50
# 7/7 [==============================] - 1s 76ms/step - loss: 0.7861 - accuracy: 0.8605 - val_loss: 0.5938 - val_accuracy: 0.9600
# Epoch 40/50
# 7/7 [==============================] - 1s 74ms/step - loss: 0.7435 - accuracy: 0.8930 - val_loss: 0.5650 - val_accuracy: 0.9600
# Epoch 41/50
# 7/7 [==============================] - 1s 79ms/step - loss: 0.7329 - accuracy: 0.8930 - val_loss: 0.5537 - val_accuracy: 0.9200
# Epoch 42/50
# 7/7 [==============================] - 1s 72ms/step - loss: 0.7536 - accuracy: 0.8512 - val_loss: 0.5399 - val_accuracy: 0.9600
# Epoch 43/50
# 7/7 [==============================] - 1s 69ms/step - loss: 0.7301 - accuracy: 0.8465 - val_loss: 0.5301 - val_accuracy: 0.9600
# Epoch 44/50
# 7/7 [==============================] - 1s 70ms/step - loss: 0.7179 - accuracy: 0.8837 - val_loss: 0.5166 - val_accuracy: 0.9600
# Epoch 45/50
# 7/7 [==============================] - 1s 81ms/step - loss: 0.6979 - accuracy: 0.8744 - val_loss: 0.4982 - val_accuracy: 0.9600
# Epoch 46/50
# 7/7 [==============================] - 1s 74ms/step - loss: 0.6779 - accuracy: 0.8930 - val_loss: 0.5023 - val_accuracy: 0.9600
# Epoch 47/50
# 7/7 [==============================] - 1s 76ms/step - loss: 0.6209 - accuracy: 0.9070 - val_loss: 0.4849 - val_accuracy: 0.9600
# Epoch 48/50
# 7/7 [==============================] - 1s 74ms/step - loss: 0.6101 - accuracy: 0.8698 - val_loss: 0.4602 - val_accuracy: 0.9600
# Epoch 49/50
# 7/7 [==============================] - 1s 82ms/step - loss: 0.6248 - accuracy: 0.8791 - val_loss: 0.4511 - val_accuracy: 0.9600
# Epoch 50/50
# 7/7 [==============================] - 1s 78ms/step - loss: 0.6268 - accuracy: 0.8930 - val_loss: 0.4333 - val_accuracy: 0.9600
